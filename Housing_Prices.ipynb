# %% [markdown]
# <a href="https://colab.research.google.com/github/gangprojects/Realtor-API/blob/main/Housing_Prices.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from datetime import datetime
import pandas as pd
import requests
import json
import seaborn as sns
import plotly.express as px

# %% [markdown]
# ## Realtor APIs

# %%
#@title API keys
api_key = "269548ab3dmsh0e2fe9f7e801cb7p10e428jsn4e0c815bca9d"

# %%
url = "https://realty-in-ca1.p.rapidapi.com/properties/get-statistics"

querystring = {"Longitude":"-122.994560","Latitude":"49.246445","CultureId":"1"}

headers = {
	"X-RapidAPI-Key": api_key,
	"X-RapidAPI-Host": "realty-in-ca1.p.rapidapi.com"
}

response = requests.request("GET", url, headers=headers, params=querystring)

# %%
all_data = response.json()

# %% [markdown]
# ## Web Json formatter is really useful

# %%
all_data
# Out:
# {'ErrorCode': {'Id': 200,
#   'Description': 'Success - OK',
#   'ProductName': 'Realtor API 7 | 20221109.3 | 660facef3b43c5755e5e5919321dc8bda7be3159 | Wednesday, November 9, 2022 10:42:45 AM',
#   'Version': '1.0.8348.28292'},
#  'Data': [{'key': '',
#    'value': [{'key': 'Daytime Population', 'value': '495'},
#     {'key': 'Number of Businesses', 'value': '8'},
#     {'key': 'Population size', 'value': '555'},
#     {'key': 'Median age', 'value': '45.3'},
#     {'key': 'Average Household Size', 'value': '2.5'},
#     {'key': 'Average Household Income', 'value': '$130,886.35'},
#     {'key': 'Households with Children (%)', 'value': '62'},
#     {'key': 'Households without Children (%)', 'value': '38'},
#     {'key': 'Number of Households', 'value': '224'}]},
#   {'key': 'Retail Sales', 'value': [{'key': '< 1', 'value': '5'}]},
#   {'key': 'Population by Age Group',
#    'value': [{'key': '0 - 4 years old', 'value': '26'},
#     {'key': '5 - 9 years old', 'value': '28'},
#     {'key': '10 - 19 years old', 'value': '65'},
#     {'key': '20 - 34 years old', 'value': '76'},
#     {'key': '35 - 49 years old', 'value': '121'},
#     {'key': '50 - 54 years old', 'value': '43'},
#     {'key': '55 - 64 years old', 'value': '101'},
#     {'key': '65 - 69 years old', 'value': '42'},
#     {'key': '70 - 79 years old', 'value': '41'},
#     {'key': '80 - 84 years old', 'value': '2'},
#     {'key': '85+ years old', 'value': '10'}]},
#   {'key': 'Population Growth/Projection',
#    'value': [{'key': '2013', 'value': '553'},
#     {'key': '2018', 'value': '555'},
#     {'key': '2021', 'value': '572'},
#     {'key': '2023', 'value': '585'},
#     {'key': '2028', 'value': '596'}]},
#   {'key': 'Education',
#    'value': [{'key': 'No cert. / Diploma / Degree', 'value': '30'},
#     {'key': 'High school', 'value': '100'},
#     {'key': 'Apprenticeship / Trade cert. / Diploma', 'value': '46'},
#     {'key': 'Non-university cert. / Diploma', 'value': '74'},
#     {'key': 'University cert. / Diploma below bachelor', 'value': '18'},
#     {'key': 'University degree', 'value': '200'}]},
#   {'key': 'Marital Status',
#    'value': [{'key': 'Married', 'value': '237'},
#     {'key': 'Common law', 'value': '53'},
#     {'key': 'Single', 'value': '119'},
#     {'key': 'Separated', 'value': '11'},
#     {'key': 'Divorced', 'value': '39'},
#     {'key': 'Widowed', 'value': '9'}]},
#   {'key': 'Languages',
#    'value': [{'key': 'English', 'value': '422'},
#     {'key': 'French', 'value': '9'},
#     {'key': 'Italian', 'value': '5'},
#     {'key': 'German', 'value': '15'},
#     {'key': 'Spanish', 'value': '14'},
#     {'key': 'Polish', 'value': '6'},
#     {'key': 'Mandarin', 'value': '12'},
#     {'key': 'Chinese n.o.s', 'value': '7'},
#     {'key': 'Russian', 'value': '5'},
#     {'key': 'Gujarati', 'value': '8'},
#     {'key': 'Romanian', 'value': '4'},
#     {'key': 'Japanese', 'value': '11'},
#     {'key': 'Czech', 'value': '6'},
#     {'key': 'Other Languages', 'value': '14'},
#     {'key': 'English & Non-Official', 'value': '7'}]},
#   {'key': 'Household income',
#    'value': [{'key': '$0 - $29,999', 'value': '19'},
#     {'key': '$30,000 - $59,999', 'value': '38'},
#     {'key': '$60,000 - $79,999', 'value': '44'},
#     {'key': '$80,000 - $99,999', 'value': '46'},
#     {'key': '$100,000 - $149,999', 'value': '52'},
#     {'key': '$150,000 - $199,999', 'value': '15'},
#     {'key': '$200,000+', 'value': '10'}]},
#   {'key': 'Children at Home',
#    'value': [{'key': '0 - 4 years old', 'value': '26'},
#     {'key': '5 - 9 years old', 'value': '28'},
#     {'key': '10 - 14 years old', 'value': '33'},
#     {'key': '15 - 19 years old', 'value': '31'},
#     {'key': '20 - 24 years old', 'value': '26'},
#     {'key': '25+ years old', 'value': '22'}]},
#   {'key': 'Ownership',
#    'value': [{'key': 'Own', 'value': '202'}, {'key': 'Rent', 'value': '22'}]},
#   {'key': 'Construction Date',
#    'value': [{'key': '1961 - 1980', 'value': '206'},
#     {'key': '1981 - 1990', 'value': '8'},
#     {'key': '1991 - 2000', 'value': '9'}]},
#   {'key': 'Occupations',
#    'value': [{'key': 'Not Applicable', 'value': '3'},
#     {'key': 'Management', 'value': '28'},
#     {'key': 'Business, Finance, Admin', 'value': '65'},
#     {'key': 'Sciences', 'value': '70'},
#     {'key': 'Health', 'value': '3'},
#     {'key': 'Social Sciences, Education, Government, Religion', 'value': '77'},
#     {'key': 'Art, Culture, Recreation, Sport', 'value': '5'},
#     {'key': 'Sales and service', 'value': '63'},
#     {'key': 'Primary Industries', 'value': '3'},
#     {'key': 'Manufacture and Utilities', 'value': '4'}]}]}

# %% [markdown]
# ## View all the contents

# %%
i = 1
for data_table in all_data['Data']:
  print('Table {0}:'.format(i),data_table['key'])
  i+=1
# Out:
# Table 1:
# Table 2: Retail Sales
# Table 3: Population by Age Group
# Table 4: Population Growth/Projection
# Table 5: Education
# Table 6: Marital Status
# Table 7: Languages
# Table 8: Household income
# Table 9: Children at Home
# Table 10: Ownership
# Table 11: Construction Date
# Table 12: Occupations

# %% [markdown]
# ## Data Exploration
# ### Table 1: General Description of the city
# - Daytime population is in abreviation by 1000
# - Population is also in abreviation by 1000

# %%
df_table_1 = pd.DataFrame(all_data['Data'][0]['value'])
df_table_1
# Out:
#                                key        value
# 0               Daytime Population          495
# 1             Number of Businesses            8
# 2                  Population size          555
# 3                       Median age         45.3
# 4           Average Household Size          2.5
# 5         Average Household Income  $130,886.35
# 6     Households with Children (%)           62
# 7  Households without Children (%)           38
# 8             Number of Households          224

# %% [markdown]
# ### Table 2: Retail Sales
# - Not much useful information about retail was provided by the Realtor APIs

# %%
df_table_2 = pd.DataFrame(all_data['Data'][1]['value'])
df_table_2
# Out:
#          key value
# 0    Unknown    86
# 1        < 1   239
# 2    1 - 4.9   466
# 3   5 - 19.9   190
# 4  20 - 99.9    64
# 5      100+     11

# %% [markdown]
# ### Table 3: Population by Age Group
# - 35 -49 years group and 55 - 64 years age group are the dominant age group in Burnaby
# - We also check consistency of the data with Table 1 of total population

# %%
df_table_3 = pd.DataFrame(all_data['Data'][2]['value'])
df_table_3['value'] = df_table_3.apply(lambda x: int(x['value']), axis = 1)
print('sum of total population:', df_table_3['value'].sum())
print('population from table 1:', df_table_1.loc[df_table_1['key'] == "Population size"]['value'].iloc[0])
df_table_3
# Out:
# sum of total population: 555
# population from table 1: 555
#                   key  value
# 0     0 - 4 years old     26
# 1     5 - 9 years old     28
# 2   10 - 19 years old     65
# 3   20 - 34 years old     76
# 4   35 - 49 years old    121
# 5   50 - 54 years old     43
# 6   55 - 64 years old    101
# 7   65 - 69 years old     42
# 8   70 - 79 years old     41
# 9   80 - 84 years old      2
# 10      85+ years old     10

# %% [markdown]
# ### Table 4: Population Growth and Projection

# %%
df_table_4 = pd.DataFrame(all_data['Data'][3]['value'])
df_table_4
# Out:
#     key value
# 0  2013   553
# 1  2018   555
# 2  2021   572
# 3  2023   585
# 4  2028   596

# %% [markdown]
# ### Table 5: Education

# %%
df_table_5 = pd.DataFrame(all_data['Data'][4]['value'])
df_table_5
# Out:
#                                          key value
# 0                No cert. / Diploma / Degree    30
# 1                                High school   100
# 2     Apprenticeship / Trade cert. / Diploma    46
# 3             Non-university cert. / Diploma    74
# 4  University cert. / Diploma below bachelor    18
# 5                          University degree   200

# %% [markdown]
# ### Table 6: Marital Status

# %%
df_table_6 = pd.DataFrame(all_data['Data'][5]['value'])
df_table_6
# Out:
#           key value
# 0     Married   237
# 1  Common law    53
# 2      Single   119
# 3   Separated    11
# 4    Divorced    39
# 5     Widowed     9

# %% [markdown]
# ## Table 7: Languages sorted by number of people

# %%
df_table_7 = pd.DataFrame(all_data['Data'][6]['value'])
df_table_7['value'] = df_table_7.apply(lambda x: int(x['value']), axis = 1)
df_table_7 = df_table_7.sort_values(by=['value'], ascending=False)
print('Length of table:', len(df_table_7))
df_table_7
# Out:
# Length of table: 15
#                        key  value
# 0                  English    422
# 3                   German     15
# 4                  Spanish     14
# 13         Other Languages     14
# 6                 Mandarin     12
# 11                Japanese     11
# 1                   French      9
# 9                 Gujarati      8
# 7            Chinese n.o.s      7
# 14  English & Non-Official      7
# 5                   Polish      6
# 12                   Czech      6
# 2                  Italian      5
# 8                  Russian      5
# 10                Romanian      4

# %% [markdown]
# ## Table 8 :Household Income

# %%
df_table_8 = pd.DataFrame(all_data['Data'][7]['value'])
df_table_8
# Out:
#                    key value
# 0         $0 - $29,999    19
# 1    $30,000 - $59,999    38
# 2    $60,000 - $79,999    44
# 3    $80,000 - $99,999    46
# 4  $100,000 - $149,999    52
# 5  $150,000 - $199,999    15
# 6            $200,000+    10

# %% [markdown]
# ## Table 9 Children at Home
# - This table is assuming for people with children only.
# - It shows a breakdown of distribution of age of children at home

# %%
df_table_9 = pd.DataFrame(all_data['Data'][8]['value'])
df_table_9
# Out:
#                  key value
# 0    0 - 4 years old    26
# 1    5 - 9 years old    28
# 2  10 - 14 years old    33
# 3  15 - 19 years old    31
# 4  20 - 24 years old    26
# 5      25+ years old    22

# %% [markdown]
# ## Table 10: Ownership

# %%
df_table_10 = pd.DataFrame(all_data['Data'][9]['value'])
df_table_10
# Out:
#     key value
# 0   Own   202
# 1  Rent    22

# %% [markdown]
# ## Table 11: Construction Date
# - The construction date is missing after 2000

# %%
df_table_11 = pd.DataFrame(all_data['Data'][10]['value'])
df_table_11.append({'key':'remaining',
                    'value': str(332)},ignore_index=True)
# Out:
#            key value
# 0  1961 - 1980   206
# 1  1981 - 1990     8
# 2  1991 - 2000     9
# 3    remaining   332

# %% [markdown]
# ## Table 12: Occupations

# %%
df_table_12 = pd.DataFrame(all_data['Data'][11]['value'])
df_table_12['value'] = df_table_12.apply(lambda x: int(x['value']), axis = 1)
df_table_12 = df_table_12.sort_values(by=['value'], ascending=False)
df_table_12
# Out:
#                                                 key  value
# 5  Social Sciences, Education, Government, Religion     77
# 3                                          Sciences     70
# 2                          Business, Finance, Admin     65
# 7                                 Sales and service     63
# 1                                        Management     28
# 6                   Art, Culture, Recreation, Sport      5
# 9                         Manufacture and Utilities      4
# 0                                    Not Applicable      3
# 4                                            Health      3
# 8                                Primary Industries      3

# %% [markdown]
# ## Greater Vancouver Area

# %%
df=[]
df = pd.DataFrame(df,columns = ['City','Latitude','Longitude'])
df['City'] = ['Vancouver, BC, Canada','North Vancouver, BC, Canada','West Vancouver, BC, Canada',
              'Richmond, BC, Canada','Burnaby, BC, Canada','Coquitlam, BC, Canada','Port Moody, BC, Canada',
              'New Westminster, BC, Canada','Surrey, BC, Canada', 'Delta, BC, Canada']

# %%
url = "https://realty-in-ca1.p.rapidapi.com/locations/auto-complete"
for i in range(df.shape[0]):
  querystring = {"Area":df['City'][i],"CultureId":"1"}

  headers = {
	"X-RapidAPI-Key": api_key,
	"X-RapidAPI-Host": "realty-in-ca1.p.rapidapi.com"
  }

  response = requests.request("GET", url, headers=headers, params=querystring)
  df['Latitude'][i] = response.json()['SubArea'][0]['Latitude']
  df['Longitude'][i] = response.json()['SubArea'][0]['Longitude']

# %%
df['Latitude'] = df['Latitude'].apply(lambda x: pd.to_numeric(x,errors='coerce'))
df['Longitude'] = df['Longitude'].apply(lambda x: pd.to_numeric(x,errors='coerce'))

# %%
df.dtypes
# Out:
# City          object
# Latitude     float64
# Longitude    float64
# dtype: object

# %%
url = "https://realty-in-ca1.p.rapidapi.com/properties/get-statistics"

jsonfile  = []


for i in range(df.shape[0]):
   
  querystring = {"Longitude":df.iloc[i,2],"Latitude":df.iloc[i,1],"CultureId":"1"}

  headers = {
	"X-RapidAPI-Key": api_key,
	"X-RapidAPI-Host": "realty-in-ca1.p.rapidapi.com"
  }

  response = requests.request("GET", url, headers=headers, params=querystring)

  all_data = response.json()
  
  jsonfile.append(all_data)

# %%
jsonfile
# Out:
# [{'ErrorCode': {'Id': 200,
#    'Description': 'Success - OK',
#    'ProductName': 'Realtor API 7 | 20221109.3 | 660facef3b43c5755e5e5919321dc8bda7be3159 | Wednesday, November 9, 2022 10:42:45 AM',
#    'Version': '1.0.8348.28292'},
#   'Data': [{'key': '',
#     'value': [{'key': 'Daytime Population', 'value': '47285'},
#      {'key': 'Number of Businesses', 'value': '2196'},
#      {'key': 'Population size', 'value': '3223'},
#      {'key': 'Median age', 'value': '34.4'},
#      {'key': 'Average Household Size', 'value': '1.6'},
#      {'key': 'Average Household Income', 'value': '$81,129.77'},
#      {'key': 'Households with Children (%)', 'value': '28'},
#      {'key': 'Households without Children (%)', 'value': '72'},
#      {'key': 'Number of Households', 'value': '1954'}]},
#    {'key': 'Retail Sales',
#     'value': [{'key': 'Unknown', 'value': '621'},
#      {'key': '< 1', 'value': '902'},
#      {'key': '1 - 4.9', 'value': '482'},
#      {'key': '5 - 19.9', 'value': '126'},
#      {'key': '20 - 99.9', 'value': '58'},
#      {'key': '100+ ', 'value': '7'}]},
#    {'key': 'Population by Age Group',
#     'value': [{'key': '0 - 4 years old', 'value': '110'},
#      {'key': '5 - 9 years old', 'value': '36'},
#      {'key': '10 - 19 years old', 'value': '78'},
#      {'key': '20 - 34 years old', 'value': '1635'},
#      {'key': '35 - 49 years old', 'value': '985'},
#      {'key': '50 - 54 years old', 'value': '185'},
#      {'key': '55 - 64 years old', 'value': '321'},
#      {'key': '65 - 69 years old', 'value': '80'},
#      {'key': '70 - 79 years old', 'value': '90'},
#      {'key': '80 - 84 years old', 'value': '16'},
#      {'key': '85+ years old', 'value': '23'}]},
#    {'key': 'Population Growth/Projection',
#     'value': [{'key': '2013', 'value': '2576'},
#      {'key': '2018', 'value': '3223'},
#      {'key': '2021', 'value': '3683'},
#      {'key': '2023', 'value': '3976'},
#      {'key': '2028', 'value': '4579'}]},
#    {'key': 'Education',
#     'value': [{'key': 'No cert. / Diploma / Degree', 'value': '104'},
#      {'key': 'High school', 'value': '394'},
#      {'key': 'Apprenticeship / Trade cert. / Diploma', 'value': '65'},
#      {'key': 'Non-university cert. / Diploma', 'value': '288'},
#      {'key': 'University cert. / Diploma below bachelor', 'value': '204'},
#      {'key': 'University degree', 'value': '2000'}]},
#    {'key': 'Marital Status',
#     'value': [{'key': 'Married', 'value': '912'},
#      {'key': 'Common law', 'value': '336'},
#      {'key': 'Single', 'value': '1477'},
#      {'key': 'Separated', 'value': '82'},
#      {'key': 'Divorced', 'value': '198'},
#      {'key': 'Widowed', 'value': '50'}]},
#    {'key': 'Languages',
#     'value': [{'key': 'English', 'value': '1695'},
#      {'key': 'French', 'value': '64'},
#      {'key': 'Italian', 'value': '9'},
#      {'key': 'German', 'value': '32'},
#      {'key': 'Punjabi', 'value': '29'},
#      {'key': 'Cantonese', 'value': '89'},
#      {'key': 'Spanish', 'value': '95'},
#      {'key': 'Arabic', 'value': '129'},
#      {'key': 'Tagalog', 'value': '26'},
#      {'key': 'Portuguese', 'value': '27'},
#      {'key': 'Polish', 'value': '11'},
#      {'key': 'Mandarin', 'value': '98'},
#      {'key': 'Chinese n.o.s', 'value': '71'},
#      {'key': 'Urdu', 'value': '12'},
#      {'key': 'Vietnamese', 'value': '14'},
#      {'key': 'Persian', 'value': '206'},
#      {'key': 'Russian', 'value': '32'},
#      {'key': 'Dutch', 'value': '2'},
#      {'key': 'Korean', 'value': '240'},
#      {'key': 'Gujarati', 'value': '10'},
#      {'key': 'Romanian', 'value': '17'},
#      {'key': 'Hindi', 'value': '4'},
#      {'key': 'Croatian', 'value': '4'},
#      {'key': 'Serbian', 'value': '10'},
#      {'key': 'Bengali', 'value': '7'},
#      {'key': 'Japanese', 'value': '91'},
#      {'key': 'Somali', 'value': '2'},
#      {'key': 'Aboriginal Languages', 'value': '4'},
#      {'key': 'Other Languages', 'value': '110'},
#      {'key': 'English & French', 'value': '2'},
#      {'key': 'English & Non-Official', 'value': '63'},
#      {'key': 'French & Non-Official', 'value': '15'}]},
#    {'key': 'Household income',
#     'value': [{'key': '$0 - $29,999', 'value': '502'},
#      {'key': '$30,000 - $59,999', 'value': '443'},
#      {'key': '$60,000 - $79,999', 'value': '296'},
#      {'key': '$80,000 - $99,999', 'value': '245'},
#      {'key': '$100,000 - $149,999', 'value': '284'},
#      {'key': '$150,000 - $199,999', 'value': '71'},
#      {'key': '$200,000+', 'value': '113'}]},
#    {'key': 'Children at Home',
#     'value': [{'key': '0 - 4 years old', 'value': '102'},
#      {'key': '5 - 9 years old', 'value': '24'},
#      {'key': '10 - 14 years old', 'value': '12'},
#      {'key': '15 - 19 years old', 'value': '36'},
#      {'key': '20 - 24 years old', 'value': '49'},
#      {'key': '25+ years old', 'value': '58'}]},
#    {'key': 'Ownership',
#     'value': [{'key': 'Own', 'value': '774'},
#      {'key': 'Rent', 'value': '1180'}]},
#    {'key': 'Construction Date',
#     'value': [{'key': '1961 - 1980', 'value': '41'},
#      {'key': '1981 - 1990', 'value': '82'},
#      {'key': '1991 - 2000', 'value': '146'},
#      {'key': '2001 - 2005', 'value': '179'},
#      {'key': '2006 - 2010', 'value': '845'},
#      {'key': '2011 - 2016', 'value': '448'},
#      {'key': 'After 2016', 'value': '213'}]},
#    {'key': 'Occupations',
#     'value': [{'key': 'Not Applicable', 'value': '29'},
#      {'key': 'Management', 'value': '331'},
#      {'key': 'Business, Finance, Admin', 'value': '652'},
#      {'key': 'Sciences', 'value': '306'},
#      {'key': 'Health', 'value': '275'},
#      {'key': 'Social Sciences, Education, Government, Religion',
#       'value': '236'},
#      {'key': 'Art, Culture, Recreation, Sport', 'value': '195'},
#      {'key': 'Sales and service', 'value': '373'},
#      {'key': 'Trades, Transport, Operators', 'value': '31'}]}]},
#  {'ErrorCode': {'Id': 200,
#    'Description': 'Success - OK',
#    'ProductName': 'Realtor API 7 | 20221109.3 | 660facef3b43c5755e5e5919321dc8bda7be3159 | Wednesday, November 9, 2022 10:42:45 AM',
#    'Version': '1.0.8348.28292'},
#   'Data': [{'key': '',
#     'value': [{'key': 'Daytime Population', 'value': '1028'},
#      {'key': 'Number of Businesses', 'value': '78'},
#      {'key': 'Population size', 'value': '1067'},
#      {'key': 'Median age', 'value': '41.8'},
#      {'key': 'Average Household Size', 'value': '2.0'},
#      {'key': 'Average Household Income', 'value': '$72,428.15'},
#      {'key': 'Households with Children (%)', 'value': '56'},
#      {'key': 'Households without Children (%)', 'value': '44'},
#      {'key': 'Number of Households', 'value': '546'}]},
#    {'key': 'Retail Sales',
#     'value': [{'key': 'Unknown', 'value': '16'},
#      {'key': '< 1', 'value': '50'},
#      {'key': '1 - 4.9', 'value': '10'},
#      {'key': '5 - 19.9', 'value': '2'}]},
#    {'key': 'Population by Age Group',
#     'value': [{'key': '0 - 4 years old', 'value': '36'},
#      {'key': '5 - 9 years old', 'value': '31'},
#      {'key': '10 - 19 years old', 'value': '88'},
#      {'key': '20 - 34 years old', 'value': '256'},
#      {'key': '35 - 49 years old', 'value': '269'},
#      {'key': '50 - 54 years old', 'value': '68'},
#      {'key': '55 - 64 years old', 'value': '143'},
#      {'key': '65 - 69 years old', 'value': '63'},
#      {'key': '70 - 79 years old', 'value': '87'},
#      {'key': '80 - 84 years old', 'value': '17'},
#      {'key': '85+ years old', 'value': '9'}]},
#    {'key': 'Population Growth/Projection',
#     'value': [{'key': '2013', 'value': '1006'},
#      {'key': '2018', 'value': '1067'},
#      {'key': '2021', 'value': '1220'},
#      {'key': '2023', 'value': '1321'},
#      {'key': '2028', 'value': '1595'}]},
#    {'key': 'Education',
#     'value': [{'key': 'No cert. / Diploma / Degree', 'value': '22'},
#      {'key': 'High school', 'value': '129'},
#      {'key': 'Apprenticeship / Trade cert. / Diploma', 'value': '89'},
#      {'key': 'Non-university cert. / Diploma', 'value': '163'},
#      {'key': 'University cert. / Diploma below bachelor', 'value': '64'},
#      {'key': 'University degree', 'value': '489'}]},
#    {'key': 'Marital Status',
#     'value': [{'key': 'Married', 'value': '400'},
#      {'key': 'Common law', 'value': '89'},
#      {'key': 'Single', 'value': '282'},
#      {'key': 'Separated', 'value': '37'},
#      {'key': 'Divorced', 'value': '102'},
#      {'key': 'Widowed', 'value': '46'}]},
#    {'key': 'Languages',
#     'value': [{'key': 'English', 'value': '490'},
#      {'key': 'French', 'value': '16'},
#      {'key': 'Italian', 'value': '2'},
#      {'key': 'German', 'value': '8'},
#      {'key': 'Punjabi', 'value': '3'},
#      {'key': 'Cantonese', 'value': '8'},
#      {'key': 'Spanish', 'value': '13'},
#      {'key': 'Arabic', 'value': '5'},
#      {'key': 'Tagalog', 'value': '15'},
#      {'key': 'Portuguese', 'value': '6'},
#      {'key': 'Polish', 'value': '5'},
#      {'key': 'Mandarin', 'value': '15'},
#      {'key': 'Chinese n.o.s', 'value': '13'},
#      {'key': 'Persian', 'value': '242'},
#      {'key': 'Russian', 'value': '3'},
#      {'key': 'Korean', 'value': '137'},
#      {'key': 'Gujarati', 'value': '4'},
#      {'key': 'Romanian', 'value': '7'},
#      {'key': 'Hungarian', 'value': '2'},
#      {'key': 'Japanese', 'value': '8'},
#      {'key': 'Turkish', 'value': '5'},
#      {'key': 'Other Languages', 'value': '29'},
#      {'key': 'English & Non-Official', 'value': '23'}]},
#    {'key': 'Household income',
#     'value': [{'key': '$0 - $29,999', 'value': '158'},
#      {'key': '$30,000 - $59,999', 'value': '164'},
#      {'key': '$60,000 - $79,999', 'value': '63'},
#      {'key': '$80,000 - $99,999', 'value': '51'},
#      {'key': '$100,000 - $149,999', 'value': '81'},
#      {'key': '$150,000 - $199,999', 'value': '21'},
#      {'key': '$200,000+', 'value': '8'}]},
#    {'key': 'Children at Home',
#     'value': [{'key': '0 - 4 years old', 'value': '36'},
#      {'key': '5 - 9 years old', 'value': '31'},
#      {'key': '10 - 14 years old', 'value': '44'},
#      {'key': '15 - 19 years old', 'value': '44'},
#      {'key': '20 - 24 years old', 'value': '18'},
#      {'key': '25+ years old', 'value': '67'}]},
#    {'key': 'Ownership',
#     'value': [{'key': 'Own', 'value': '264'},
#      {'key': 'Rent', 'value': '282'}]},
#    {'key': 'Construction Date',
#     'value': [{'key': 'Before 1960', 'value': '26'},
#      {'key': '1961 - 1980', 'value': '113'},
#      {'key': '1981 - 1990', 'value': '6'},
#      {'key': '1991 - 2000', 'value': '77'},
#      {'key': '2001 - 2005', 'value': '23'},
#      {'key': '2006 - 2010', 'value': '239'},
#      {'key': '2011 - 2016', 'value': '39'},
#      {'key': 'After 2016', 'value': '23'}]},
#    {'key': 'Occupations',
#     'value': [{'key': 'Not Applicable', 'value': '5'},
#      {'key': 'Management', 'value': '55'},
#      {'key': 'Business, Finance, Admin', 'value': '113'},
#      {'key': 'Sciences', 'value': '101'},
#      {'key': 'Health', 'value': '25'},
#      {'key': 'Social Sciences, Education, Government, Religion',
#       'value': '90'},
#      {'key': 'Art, Culture, Recreation, Sport', 'value': '9'},
#      {'key': 'Sales and service', 'value': '117'},
#      {'key': 'Trades, Transport, Operators', 'value': '77'},
#      {'key': 'Primary Industries', 'value': '2'},
#      {'key': 'Manufacture and Utilities', 'value': '10'}]}]},
#  {'ErrorCode': {'Id': 200,
#    'Description': 'Success - OK',
#    'ProductName': 'Realtor API 7 | 20221109.3 | 660facef3b43c5755e5e5919321dc8bda7be3159 | Wednesday, November 9, 2022 10:42:45 AM',
#    'Version': '1.0.8348.28292'},
#   'Data': [{'key': '',
#     'value': [{'key': 'Daytime Population', 'value': '2388'},
#      {'key': 'Number of Businesses', 'value': '181'},
#      {'key': 'Population size', 'value': '561'},
#      {'key': 'Median age', 'value': '53.9'},
#      {'key': 'Average Household Size', 'value': '1.7'},
#      {'key': 'Average Household Income', 'value': '$83,160.77'},
#      {'key': 'Households with Children (%)', 'value': '51'},
#      {'key': 'Households without Children (%)', 'value': '49'},
#      {'key': 'Number of Households', 'value': '323'}]},
#    {'key': 'Retail Sales',
#     'value': [{'key': 'Unknown', 'value': '31'},
#      {'key': '< 1', 'value': '115'},
#      {'key': '1 - 4.9', 'value': '31'},
#      {'key': '5 - 19.9', 'value': '3'}]},
#    {'key': 'Population by Age Group',
#     'value': [{'key': '0 - 4 years old', 'value': '15'},
#      {'key': '5 - 9 years old', 'value': '24'},
#      {'key': '10 - 19 years old', 'value': '42'},
#      {'key': '20 - 34 years old', 'value': '55'},
#      {'key': '35 - 49 years old', 'value': '114'},
#      {'key': '50 - 54 years old', 'value': '43'},
#      {'key': '55 - 64 years old', 'value': '86'},
#      {'key': '65 - 69 years old', 'value': '44'},
#      {'key': '70 - 79 years old', 'value': '79'},
#      {'key': '80 - 84 years old', 'value': '32'},
#      {'key': '85+ years old', 'value': '33'}]},
#    {'key': 'Population Growth/Projection',
#     'value': [{'key': '2013', 'value': '6030'},
#      {'key': '2018', 'value': '561'},
#      {'key': '2021', 'value': '6376'},
#      {'key': '2023', 'value': '6534'},
#      {'key': '2028', 'value': '6898'}]},
#    {'key': 'Education',
#     'value': [{'key': 'No cert. / Diploma / Degree', 'value': '54'},
#      {'key': 'High school', 'value': '102'},
#      {'key': 'Apprenticeship / Trade cert. / Diploma', 'value': '44'},
#      {'key': 'Non-university cert. / Diploma', 'value': '72'},
#      {'key': 'University cert. / Diploma below bachelor', 'value': '3'},
#      {'key': 'University degree', 'value': '231'}]},
#    {'key': 'Marital Status',
#     'value': [{'key': 'Married', 'value': '216'},
#      {'key': 'Common law', 'value': '19'},
#      {'key': 'Single', 'value': '124'},
#      {'key': 'Separated', 'value': '21'},
#      {'key': 'Divorced', 'value': '75'},
#      {'key': 'Widowed', 'value': '51'}]},
#    {'key': 'Languages',
#     'value': [{'key': 'English', 'value': '356'},
#      {'key': 'French', 'value': '5'},
#      {'key': 'German', 'value': '8'},
#      {'key': 'Cantonese', 'value': '6'},
#      {'key': 'Spanish', 'value': '5'},
#      {'key': 'Arabic', 'value': '6'},
#      {'key': 'Mandarin', 'value': '9'},
#      {'key': 'Chinese n.o.s', 'value': '15'},
#      {'key': 'Urdu', 'value': '7'},
#      {'key': 'Ukrainian', 'value': '3'},
#      {'key': 'Persian', 'value': '63'},
#      {'key': 'Russian', 'value': '6'},
#      {'key': 'Dutch', 'value': '3'},
#      {'key': 'Korean', 'value': '24'},
#      {'key': 'Gujarati', 'value': '2'},
#      {'key': 'Hungarian', 'value': '2'},
#      {'key': 'Croatian', 'value': '3'},
#      {'key': 'Serbian', 'value': '4'},
#      {'key': 'Bengali', 'value': '6'},
#      {'key': 'Japanese', 'value': '5'},
#      {'key': 'Czech', 'value': '4'},
#      {'key': 'Other Languages', 'value': '7'},
#      {'key': 'English & Non-Official', 'value': '3'},
#      {'key': 'French & Non-Official', 'value': '5'}]},
#    {'key': 'Household income',
#     'value': [{'key': '$0 - $29,999', 'value': '131'},
#      {'key': '$30,000 - $59,999', 'value': '101'},
#      {'key': '$60,000 - $79,999', 'value': '30'},
#      {'key': '$80,000 - $99,999', 'value': '5'},
#      {'key': '$100,000 - $149,999', 'value': '4'},
#      {'key': '$200,000+', 'value': '52'}]},
#    {'key': 'Children at Home',
#     'value': [{'key': '0 - 4 years old', 'value': '12'},
#      {'key': '5 - 9 years old', 'value': '21'},
#      {'key': '10 - 14 years old', 'value': '16'},
#      {'key': '15 - 19 years old', 'value': '21'},
#      {'key': '20 - 24 years old', 'value': '11'},
#      {'key': '25+ years old', 'value': '26'}]},
#    {'key': 'Ownership',
#     'value': [{'key': 'Own', 'value': '96'}, {'key': 'Rent', 'value': '227'}]},
#    {'key': 'Construction Date',
#     'value': [{'key': 'Before 1960', 'value': '48'},
#      {'key': '1961 - 1980', 'value': '179'},
#      {'key': '1981 - 1990', 'value': '38'},
#      {'key': '1991 - 2000', 'value': '30'},
#      {'key': '2001 - 2005', 'value': '17'},
#      {'key': 'After 2016', 'value': '11'}]},
#    {'key': 'Occupations',
#     'value': [{'key': 'Not Applicable', 'value': '2'},
#      {'key': 'Management', 'value': '18'},
#      {'key': 'Business, Finance, Admin', 'value': '63'},
#      {'key': 'Health', 'value': '27'},
#      {'key': 'Social Sciences, Education, Government, Religion',
#       'value': '31'},
#      {'key': 'Art, Culture, Recreation, Sport', 'value': '73'},
#      {'key': 'Sales and service', 'value': '40'},
#      {'key': 'Trades, Transport, Operators', 'value': '5'},
#      {'key': 'Manufacture and Utilities', 'value': '5'}]}]},
#  {'ErrorCode': {'Id': 200,
#    'Description': 'Success - OK',
#    'ProductName': 'Realtor API 7 | 20221109.3 | 660facef3b43c5755e5e5919321dc8bda7be3159 | Wednesday, November 9, 2022 10:42:45 AM',
#    'Version': '1.0.8348.28292'},
#   'Data': [{'key': '',
#     'value': [{'key': 'Daytime Population', 'value': '498'},
#      {'key': 'Number of Businesses', 'value': '11'},
#      {'key': 'Population size', 'value': '883'},
#      {'key': 'Median age', 'value': '49.9'},
#      {'key': 'Average Household Size', 'value': '2.2'},
#      {'key': 'Average Household Income', 'value': '$62,573.07'},
#      {'key': 'Households with Children (%)', 'value': '64'},
#      {'key': 'Households without Children (%)', 'value': '36'},
#      {'key': 'Number of Households', 'value': '403'}]},
#    {'key': 'Retail Sales',
#     'value': [{'key': '< 1', 'value': '7'}, {'key': '1 - 4.9', 'value': '4'}]},
#    {'key': 'Population by Age Group',
#     'value': [{'key': '0 - 4 years old', 'value': '24'},
#      {'key': '5 - 9 years old', 'value': '12'},
#      {'key': '10 - 19 years old', 'value': '54'},
#      {'key': '20 - 34 years old', 'value': '204'},
#      {'key': '35 - 49 years old', 'value': '149'},
#      {'key': '50 - 54 years old', 'value': '61'},
#      {'key': '55 - 64 years old', 'value': '177'},
#      {'key': '65 - 69 years old', 'value': '65'},
#      {'key': '70 - 79 years old', 'value': '82'},
#      {'key': '80 - 84 years old', 'value': '23'},
#      {'key': '85+ years old', 'value': '32'}]},
#    {'key': 'Population Growth/Projection',
#     'value': [{'key': '2013', 'value': '901'},
#      {'key': '2018', 'value': '883'},
#      {'key': '2021', 'value': '890'},
#      {'key': '2023', 'value': '895'},
#      {'key': '2028', 'value': '903'}]},
#    {'key': 'Education',
#     'value': [{'key': 'No cert. / Diploma / Degree', 'value': '73'},
#      {'key': 'High school', 'value': '220'},
#      {'key': 'Apprenticeship / Trade cert. / Diploma', 'value': '53'},
#      {'key': 'Non-university cert. / Diploma', 'value': '70'},
#      {'key': 'University cert. / Diploma below bachelor', 'value': '59'},
#      {'key': 'University degree', 'value': '352'}]},
#    {'key': 'Marital Status',
#     'value': [{'key': 'Married', 'value': '386'},
#      {'key': 'Common law', 'value': '25'},
#      {'key': 'Single', 'value': '266'},
#      {'key': 'Separated', 'value': '22'},
#      {'key': 'Divorced', 'value': '75'},
#      {'key': 'Widowed', 'value': '53'}]},
#    {'key': 'Languages',
#     'value': [{'key': 'English', 'value': '137'},
#      {'key': 'French', 'value': '6'},
#      {'key': 'Cantonese', 'value': '148'},
#      {'key': 'Spanish', 'value': '11'},
#      {'key': 'Arabic', 'value': '7'},
#      {'key': 'Tagalog', 'value': '112'},
#      {'key': 'Mandarin', 'value': '177'},
#      {'key': 'Chinese n.o.s', 'value': '170'},
#      {'key': 'Persian', 'value': '8'},
#      {'key': 'Russian', 'value': '6'},
#      {'key': 'Korean', 'value': '6'},
#      {'key': 'Japanese', 'value': '10'},
#      {'key': 'Other Languages', 'value': '45'},
#      {'key': 'English & Non-Official', 'value': '34'}]},
#    {'key': 'Household income',
#     'value': [{'key': '$0 - $29,999', 'value': '178'},
#      {'key': '$30,000 - $59,999', 'value': '127'},
#      {'key': '$60,000 - $79,999', 'value': '39'},
#      {'key': '$80,000 - $99,999', 'value': '19'},
#      {'key': '$100,000 - $149,999', 'value': '32'},
#      {'key': '$150,000 - $199,999', 'value': '4'},
#      {'key': '$200,000+', 'value': '4'}]},
#    {'key': 'Children at Home',
#     'value': [{'key': '0 - 4 years old', 'value': '24'},
#      {'key': '5 - 9 years old', 'value': '12'},
#      {'key': '10 - 14 years old', 'value': '20'},
#      {'key': '15 - 19 years old', 'value': '32'},
#      {'key': '20 - 24 years old', 'value': '37'},
#      {'key': '25+ years old', 'value': '100'}]},
#    {'key': 'Ownership',
#     'value': [{'key': 'Own', 'value': '220'},
#      {'key': 'Rent', 'value': '183'}]},
#    {'key': 'Construction Date',
#     'value': [{'key': 'Before 1960', 'value': '20'},
#      {'key': '1961 - 1980', 'value': '154'},
#      {'key': '1981 - 1990', 'value': '51'},
#      {'key': '1991 - 2000', 'value': '150'},
#      {'key': '2001 - 2005', 'value': '27'}]},
#    {'key': 'Occupations',
#     'value': [{'key': 'Not Applicable', 'value': '12'},
#      {'key': 'Management', 'value': '86'},
#      {'key': 'Business, Finance, Admin', 'value': '69'},
#      {'key': 'Sciences', 'value': '4'},
#      {'key': 'Social Sciences, Education, Government, Religion',
#       'value': '46'},
#      {'key': 'Art, Culture, Recreation, Sport', 'value': '16'},
#      {'key': 'Sales and service', 'value': '149'},
#      {'key': 'Trades, Transport, Operators', 'value': '37'},
#      {'key': 'Manufacture and Utilities', 'value': '27'}]}]},
#  {'ErrorCode': {'Id': 200,
#    'Description': 'Success - OK',
#    'ProductName': 'Realtor API 7 | 20221109.3 | 660facef3b43c5755e5e5919321dc8bda7be3159 | Wednesday, November 9, 2022 10:42:45 AM',
#    'Version': '1.0.8348.28292'},
#   'Data': [{'key': '',
#     'value': [{'key': 'Daytime Population', 'value': '274'},
#      {'key': 'Number of Businesses', 'value': '5'},
#      {'key': 'Population size', 'value': '535'},
#      {'key': 'Median age', 'value': '40.1'},
#      {'key': 'Average Household Size', 'value': '3.1'},
#      {'key': 'Average Household Income', 'value': '$88,593.16'},
#      {'key': 'Households with Children (%)', 'value': '64'},
#      {'key': 'Households without Children (%)', 'value': '36'},
#      {'key': 'Number of Households', 'value': '174'}]},
#    {'key': 'Retail Sales',
#     'value': [{'key': 'Unknown', 'value': '2'}, {'key': '< 1', 'value': '3'}]},
#    {'key': 'Population by Age Group',
#     'value': [{'key': '0 - 4 years old', 'value': '24'},
#      {'key': '5 - 9 years old', 'value': '24'},
#      {'key': '10 - 19 years old', 'value': '55'},
#      {'key': '20 - 34 years old', 'value': '133'},
#      {'key': '35 - 49 years old', 'value': '91'},
#      {'key': '50 - 54 years old', 'value': '40'},
#      {'key': '55 - 64 years old', 'value': '79'},
#      {'key': '65 - 69 years old', 'value': '32'},
#      {'key': '70 - 79 years old', 'value': '39'},
#      {'key': '80 - 84 years old', 'value': '9'},
#      {'key': '85+ years old', 'value': '9'}]},
#    {'key': 'Population Growth/Projection',
#     'value': [{'key': '2013', 'value': '402'},
#      {'key': '2018', 'value': '535'},
#      {'key': '2021', 'value': '556'},
#      {'key': '2023', 'value': '569'},
#      {'key': '2028', 'value': '584'}]},
#    {'key': 'Education',
#     'value': [{'key': 'No cert. / Diploma / Degree', 'value': '46'},
#      {'key': 'High school', 'value': '179'},
#      {'key': 'Apprenticeship / Trade cert. / Diploma', 'value': '2'},
#      {'key': 'Non-university cert. / Diploma', 'value': '76'},
#      {'key': 'University cert. / Diploma below bachelor', 'value': '3'},
#      {'key': 'University degree', 'value': '156'}]},
#    {'key': 'Marital Status',
#     'value': [{'key': 'Married', 'value': '245'},
#      {'key': 'Common law', 'value': '22'},
#      {'key': 'Single', 'value': '144'},
#      {'key': 'Separated', 'value': '15'},
#      {'key': 'Divorced', 'value': '18'},
#      {'key': 'Widowed', 'value': '18'}]},
#    {'key': 'Languages',
#     'value': [{'key': 'English', 'value': '305'},
#      {'key': 'French', 'value': '7'},
#      {'key': 'German', 'value': '7'},
#      {'key': 'Punjabi', 'value': '27'},
#      {'key': 'Cantonese', 'value': '56'},
#      {'key': 'Tagalog', 'value': '9'},
#      {'key': 'Portuguese', 'value': '8'},
#      {'key': 'Mandarin', 'value': '28'},
#      {'key': 'Chinese n.o.s', 'value': '21'},
#      {'key': 'Persian', 'value': '11'},
#      {'key': 'Korean', 'value': '9'},
#      {'key': 'Hindi', 'value': '10'},
#      {'key': 'Japanese', 'value': '7'},
#      {'key': 'Other Languages', 'value': '17'},
#      {'key': 'English & Non-Official', 'value': '13'}]},
#    {'key': 'Household income',
#     'value': [{'key': '$0 - $29,999', 'value': '47'},
#      {'key': '$30,000 - $59,999', 'value': '40'},
#      {'key': '$60,000 - $79,999', 'value': '18'},
#      {'key': '$80,000 - $99,999', 'value': '21'},
#      {'key': '$100,000 - $149,999', 'value': '32'},
#      {'key': '$150,000 - $199,999', 'value': '14'},
#      {'key': '$200,000+', 'value': '2'}]},
#    {'key': 'Children at Home',
#     'value': [{'key': '0 - 4 years old', 'value': '20'},
#      {'key': '5 - 9 years old', 'value': '16'},
#      {'key': '10 - 14 years old', 'value': '25'},
#      {'key': '15 - 19 years old', 'value': '30'},
#      {'key': '20 - 24 years old', 'value': '21'},
#      {'key': '25+ years old', 'value': '54'}]},
#    {'key': 'Ownership',
#     'value': [{'key': 'Own', 'value': '135'}, {'key': 'Rent', 'value': '39'}]},
#    {'key': 'Construction Date',
#     'value': [{'key': 'Before 1960', 'value': '25'},
#      {'key': '1961 - 1980', 'value': '74'},
#      {'key': '1981 - 1990', 'value': '23'},
#      {'key': '1991 - 2000', 'value': '16'},
#      {'key': 'After 2016', 'value': '36'}]},
#    {'key': 'Occupations',
#     'value': [{'key': 'Not Applicable', 'value': '6'},
#      {'key': 'Management', 'value': '44'},
#      {'key': 'Business, Finance, Admin', 'value': '72'},
#      {'key': 'Sciences', 'value': '56'},
#      {'key': 'Health', 'value': '2'},
#      {'key': 'Art, Culture, Recreation, Sport', 'value': '2'},
#      {'key': 'Sales and service', 'value': '78'},
#      {'key': 'Trades, Transport, Operators', 'value': '33'},
#      {'key': 'Manufacture and Utilities', 'value': '4'}]}]},
#  {'ErrorCode': {'Id': 200,
#    'Description': 'Success - OK',
#    'ProductName': 'Realtor API 7 | 20221109.3 | 660facef3b43c5755e5e5919321dc8bda7be3159 | Wednesday, November 9, 2022 10:42:45 AM',
#    'Version': '1.0.8348.28292'},
#   'Data': [{'key': '',
#     'value': [{'key': 'Daytime Population', 'value': '8724'},
#      {'key': 'Number of Businesses', 'value': '342'},
#      {'key': 'Population size', 'value': '5989'},
#      {'key': 'Median age', 'value': '36.1'},
#      {'key': 'Average Household Size', 'value': '2.0'},
#      {'key': 'Average Household Income', 'value': '$61,662.28'},
#      {'key': 'Households with Children (%)', 'value': '59'},
#      {'key': 'Households without Children (%)', 'value': '41'},
#      {'key': 'Number of Households', 'value': '2988'}]},
#    {'key': 'Retail Sales',
#     'value': [{'key': 'Unknown', 'value': '16'},
#      {'key': '< 1', 'value': '218'},
#      {'key': '1 - 4.9', 'value': '90'},
#      {'key': '5 - 19.9', 'value': '14'},
#      {'key': '20 - 99.9', 'value': '4'}]},
#    {'key': 'Population by Age Group',
#     'value': [{'key': '0 - 4 years old', 'value': '312'},
#      {'key': '5 - 9 years old', 'value': '224'},
#      {'key': '10 - 19 years old', 'value': '499'},
#      {'key': '20 - 34 years old', 'value': '1830'},
#      {'key': '35 - 49 years old', 'value': '1488'},
#      {'key': '50 - 54 years old', 'value': '307'},
#      {'key': '55 - 64 years old', 'value': '596'},
#      {'key': '65 - 69 years old', 'value': '250'},
#      {'key': '70 - 79 years old', 'value': '339'},
#      {'key': '80 - 84 years old', 'value': '91'},
#      {'key': '85+ years old', 'value': '72'}]},
#    {'key': 'Population Growth/Projection',
#     'value': [{'key': '2013', 'value': '4112'},
#      {'key': '2018', 'value': '5989'},
#      {'key': '2021', 'value': '6576'},
#      {'key': '2023', 'value': '6973'},
#      {'key': '2028', 'value': '8000'}]},
#    {'key': 'Education',
#     'value': [{'key': 'No cert. / Diploma / Degree', 'value': '530'},
#      {'key': 'High school', 'value': '1386'},
#      {'key': 'Apprenticeship / Trade cert. / Diploma', 'value': '192'},
#      {'key': 'Non-university cert. / Diploma', 'value': '716'},
#      {'key': 'University cert. / Diploma below bachelor', 'value': '576'},
#      {'key': 'University degree', 'value': '1882'}]},
#    {'key': 'Marital Status',
#     'value': [{'key': 'Married', 'value': '2477'},
#      {'key': 'Common law', 'value': '380'},
#      {'key': 'Single', 'value': '1679'},
#      {'key': 'Separated', 'value': '182'},
#      {'key': 'Divorced', 'value': '352'},
#      {'key': 'Widowed', 'value': '212'}]},
#    {'key': 'Languages',
#     'value': [{'key': 'English', 'value': '1904'},
#      {'key': 'French', 'value': '37'},
#      {'key': 'Italian', 'value': '10'},
#      {'key': 'German', 'value': '23'},
#      {'key': 'Punjabi', 'value': '68'},
#      {'key': 'Cantonese', 'value': '187'},
#      {'key': 'Spanish', 'value': '63'},
#      {'key': 'Arabic', 'value': '96'},
#      {'key': 'Tagalog', 'value': '120'},
#      {'key': 'Portuguese', 'value': '2'},
#      {'key': 'Polish', 'value': '31'},
#      {'key': 'Mandarin', 'value': '312'},
#      {'key': 'Chinese n.o.s', 'value': '262'},
#      {'key': 'Urdu', 'value': '3'},
#      {'key': 'Vietnamese', 'value': '21'},
#      {'key': 'Ukrainian', 'value': '19'},
#      {'key': 'Persian', 'value': '1250'},
#      {'key': 'Russian', 'value': '109'},
#      {'key': 'Dutch', 'value': '9'},
#      {'key': 'Korean', 'value': '997'},
#      {'key': 'Greek', 'value': '5'},
#      {'key': 'Tamil', 'value': '4'},
#      {'key': 'Gujarati', 'value': '7'},
#      {'key': 'Romanian', 'value': '27'},
#      {'key': 'Hindi', 'value': '12'},
#      {'key': 'Hungarian', 'value': '12'},
#      {'key': 'Croatian', 'value': '16'},
#      {'key': 'Serbian', 'value': '8'},
#      {'key': 'Bengali', 'value': '2'},
#      {'key': 'Japanese', 'value': '24'},
#      {'key': 'Turkish', 'value': '9'},
#      {'key': 'Czech', 'value': '14'},
#      {'key': 'Other Languages', 'value': '208'},
#      {'key': 'English & French', 'value': '10'},
#      {'key': 'English & Non-Official', 'value': '99'},
#      {'key': 'English & French & Non-Official', 'value': '8'}]},
#    {'key': 'Household income',
#     'value': [{'key': '$0 - $29,999', 'value': '926'},
#      {'key': '$30,000 - $59,999', 'value': '888'},
#      {'key': '$60,000 - $79,999', 'value': '499'},
#      {'key': '$80,000 - $99,999', 'value': '253'},
#      {'key': '$100,000 - $149,999', 'value': '309'},
#      {'key': '$150,000 - $199,999', 'value': '56'},
#      {'key': '$200,000+', 'value': '57'}]},
#    {'key': 'Children at Home',
#     'value': [{'key': '0 - 4 years old', 'value': '309'},
#      {'key': '5 - 9 years old', 'value': '224'},
#      {'key': '10 - 14 years old', 'value': '171'},
#      {'key': '15 - 19 years old', 'value': '279'},
#      {'key': '20 - 24 years old', 'value': '172'},
#      {'key': '25+ years old', 'value': '246'}]},
#    {'key': 'Ownership',
#     'value': [{'key': 'Own', 'value': '1420'},
#      {'key': 'Rent', 'value': '1568'}]},
#    {'key': 'Construction Date',
#     'value': [{'key': '1961 - 1980', 'value': '7'},
#      {'key': '1981 - 1990', 'value': '101'},
#      {'key': '1991 - 2000', 'value': '365'},
#      {'key': '2001 - 2005', 'value': '127'},
#      {'key': '2006 - 2010', 'value': '796'},
#      {'key': '2011 - 2016', 'value': '1528'},
#      {'key': 'After 2016', 'value': '64'}]},
#    {'key': 'Occupations',
#     'value': [{'key': 'Not Applicable', 'value': '111'},
#      {'key': 'Management', 'value': '434'},
#      {'key': 'Business, Finance, Admin', 'value': '782'},
#      {'key': 'Sciences', 'value': '442'},
#      {'key': 'Health', 'value': '73'},
#      {'key': 'Social Sciences, Education, Government, Religion',
#       'value': '316'},
#      {'key': 'Art, Culture, Recreation, Sport', 'value': '117'},
#      {'key': 'Sales and service', 'value': '745'},
#      {'key': 'Trades, Transport, Operators', 'value': '443'},
#      {'key': 'Primary Industries', 'value': '5'},
#      {'key': 'Manufacture and Utilities', 'value': '56'}]}]},
#  {'ErrorCode': {'Id': 200,
#    'Description': 'Success - OK',
#    'ProductName': 'Realtor API 7 | 20221109.3 | 660facef3b43c5755e5e5919321dc8bda7be3159 | Wednesday, November 9, 2022 10:42:45 AM',
#    'Version': '1.0.8348.28292'},
#   'Data': [{'key': '',
#     'value': [{'key': 'Daytime Population', 'value': '467'},
#      {'key': 'Number of Businesses', 'value': '6'},
#      {'key': 'Population size', 'value': '1031'},
#      {'key': 'Median age', 'value': '39.8'},
#      {'key': 'Average Household Size', 'value': '2.5'},
#      {'key': 'Average Household Income', 'value': '$102,134.85'},
#      {'key': 'Households with Children (%)', 'value': '66'},
#      {'key': 'Households without Children (%)', 'value': '34'},
#      {'key': 'Number of Households', 'value': '406'}]},
#    {'key': 'Retail Sales', 'value': [{'key': '< 1', 'value': '4'}]},
#    {'key': 'Population by Age Group',
#     'value': [{'key': '0 - 4 years old', 'value': '67'},
#      {'key': '5 - 9 years old', 'value': '61'},
#      {'key': '10 - 19 years old', 'value': '111'},
#      {'key': '20 - 34 years old', 'value': '198'},
#      {'key': '35 - 49 years old', 'value': '250'},
#      {'key': '50 - 54 years old', 'value': '83'},
#      {'key': '55 - 64 years old', 'value': '156'},
#      {'key': '65 - 69 years old', 'value': '47'},
#      {'key': '70 - 79 years old', 'value': '45'},
#      {'key': '80 - 84 years old', 'value': '9'},
#      {'key': '85+ years old', 'value': '4'}]},
#    {'key': 'Population Growth/Projection',
#     'value': [{'key': '2013', 'value': '1048'},
#      {'key': '2018', 'value': '1031'},
#      {'key': '2021', 'value': '1035'},
#      {'key': '2023', 'value': '1040'},
#      {'key': '2028', 'value': '1030'}]},
#    {'key': 'Education',
#     'value': [{'key': 'No cert. / Diploma / Degree', 'value': '55'},
#      {'key': 'High school', 'value': '203'},
#      {'key': 'Apprenticeship / Trade cert. / Diploma', 'value': '75'},
#      {'key': 'Non-university cert. / Diploma', 'value': '158'},
#      {'key': 'University cert. / Diploma below bachelor', 'value': '88'},
#      {'key': 'University degree', 'value': '272'}]},
#    {'key': 'Marital Status',
#     'value': [{'key': 'Married', 'value': '420'},
#      {'key': 'Common law', 'value': '63'},
#      {'key': 'Single', 'value': '258'},
#      {'key': 'Separated', 'value': '32'},
#      {'key': 'Divorced', 'value': '54'},
#      {'key': 'Widowed', 'value': '24'}]},
#    {'key': 'Languages',
#     'value': [{'key': 'English', 'value': '737'},
#      {'key': 'French', 'value': '20'},
#      {'key': 'Italian', 'value': '2'},
#      {'key': 'German', 'value': '18'},
#      {'key': 'Punjabi', 'value': '5'},
#      {'key': 'Cantonese', 'value': '8'},
#      {'key': 'Spanish', 'value': '19'},
#      {'key': 'Arabic', 'value': '4'},
#      {'key': 'Tagalog', 'value': '14'},
#      {'key': 'Polish', 'value': '3'},
#      {'key': 'Mandarin', 'value': '21'},
#      {'key': 'Chinese n.o.s', 'value': '8'},
#      {'key': 'Urdu', 'value': '5'},
#      {'key': 'Vietnamese', 'value': '10'},
#      {'key': 'Persian', 'value': '20'},
#      {'key': 'Russian', 'value': '12'},
#      {'key': 'Korean', 'value': '5'},
#      {'key': 'Greek', 'value': '5'},
#      {'key': 'Gujarati', 'value': '13'},
#      {'key': 'Romanian', 'value': '18'},
#      {'key': 'Hindi', 'value': '6'},
#      {'key': 'Hungarian', 'value': '4'},
#      {'key': 'Bengali', 'value': '6'},
#      {'key': 'Japanese', 'value': '11'},
#      {'key': 'Czech', 'value': '9'},
#      {'key': 'Other Languages', 'value': '21'},
#      {'key': 'English & French', 'value': '5'},
#      {'key': 'English & Non-Official', 'value': '11'},
#      {'key': 'French & Non-Official', 'value': '4'}]},
#    {'key': 'Household income',
#     'value': [{'key': '$0 - $29,999', 'value': '36'},
#      {'key': '$30,000 - $59,999', 'value': '90'},
#      {'key': '$60,000 - $79,999', 'value': '81'},
#      {'key': '$80,000 - $99,999', 'value': '61'},
#      {'key': '$100,000 - $149,999', 'value': '86'},
#      {'key': '$150,000 - $199,999', 'value': '42'},
#      {'key': '$200,000+', 'value': '10'}]},
#    {'key': 'Children at Home',
#     'value': [{'key': '0 - 4 years old', 'value': '64'},
#      {'key': '5 - 9 years old', 'value': '61'},
#      {'key': '10 - 14 years old', 'value': '47'},
#      {'key': '15 - 19 years old', 'value': '59'},
#      {'key': '20 - 24 years old', 'value': '47'},
#      {'key': '25+ years old', 'value': '51'}]},
#    {'key': 'Ownership',
#     'value': [{'key': 'Own', 'value': '305'},
#      {'key': 'Rent', 'value': '101'}]},
#    {'key': 'Construction Date',
#     'value': [{'key': 'Before 1960', 'value': '10'},
#      {'key': '1961 - 1980', 'value': '284'},
#      {'key': '1981 - 1990', 'value': '46'},
#      {'key': '1991 - 2000', 'value': '39'},
#      {'key': '2006 - 2010', 'value': '23'},
#      {'key': 'After 2016', 'value': '4'}]},
#    {'key': 'Occupations',
#     'value': [{'key': 'Not Applicable', 'value': '5'},
#      {'key': 'Management', 'value': '68'},
#      {'key': 'Business, Finance, Admin', 'value': '119'},
#      {'key': 'Sciences', 'value': '61'},
#      {'key': 'Health', 'value': '49'},
#      {'key': 'Social Sciences, Education, Government, Religion',
#       'value': '74'},
#      {'key': 'Art, Culture, Recreation, Sport', 'value': '38'},
#      {'key': 'Sales and service', 'value': '138'},
#      {'key': 'Trades, Transport, Operators', 'value': '105'},
#      {'key': 'Primary Industries', 'value': '2'},
#      {'key': 'Manufacture and Utilities', 'value': '9'}]}]},
#  {'ErrorCode': {'Id': 200,
#    'Description': 'Success - OK',
#    'ProductName': 'Realtor API 7 | 20221109.3 | 660facef3b43c5755e5e5919321dc8bda7be3159 | Wednesday, November 9, 2022 10:42:45 AM',
#    'Version': '1.0.8348.28292'},
#   'Data': [{'key': '',
#     'value': [{'key': 'Daytime Population', 'value': '4007'},
#      {'key': 'Number of Businesses', 'value': '280'},
#      {'key': 'Population size', 'value': '2095'},
#      {'key': 'Median age', 'value': '36.7'},
#      {'key': 'Average Household Size', 'value': '1.8'},
#      {'key': 'Average Household Income', 'value': '$138,014.25'},
#      {'key': 'Households with Children (%)', 'value': '34'},
#      {'key': 'Households without Children (%)', 'value': '66'},
#      {'key': 'Number of Households', 'value': '1176'}]},
#    {'key': 'Retail Sales',
#     'value': [{'key': 'Unknown', 'value': '68'},
#      {'key': '< 1', 'value': '158'},
#      {'key': '1 - 4.9', 'value': '46'},
#      {'key': '5 - 19.9', 'value': '6'},
#      {'key': '20 - 99.9', 'value': '2'}]},
#    {'key': 'Population by Age Group',
#     'value': [{'key': '0 - 4 years old', 'value': '92'},
#      {'key': '5 - 9 years old', 'value': '36'},
#      {'key': '10 - 19 years old', 'value': '49'},
#      {'key': '20 - 34 years old', 'value': '812'},
#      {'key': '35 - 49 years old', 'value': '596'},
#      {'key': '50 - 54 years old', 'value': '136'},
#      {'key': '55 - 64 years old', 'value': '262'},
#      {'key': '65 - 69 years old', 'value': '80'},
#      {'key': '70 - 79 years old', 'value': '87'},
#      {'key': '80 - 84 years old', 'value': '9'},
#      {'key': '85+ years old', 'value': '19'}]},
#    {'key': 'Population Growth/Projection',
#     'value': [{'key': '2013', 'value': '1757'},
#      {'key': '2018', 'value': '2095'},
#      {'key': '2021', 'value': '2491'},
#      {'key': '2023', 'value': '2753'},
#      {'key': '2028', 'value': '3637'}]},
#    {'key': 'Education',
#     'value': [{'key': 'No cert. / Diploma / Degree', 'value': '68'},
#      {'key': 'High school', 'value': '306'},
#      {'key': 'Apprenticeship / Trade cert. / Diploma', 'value': '85'},
#      {'key': 'Non-university cert. / Diploma', 'value': '369'},
#      {'key': 'University cert. / Diploma below bachelor', 'value': '240'},
#      {'key': 'University degree', 'value': '880'}]},
#    {'key': 'Marital Status',
#     'value': [{'key': 'Married', 'value': '711'},
#      {'key': 'Common law', 'value': '315'},
#      {'key': 'Single', 'value': '645'},
#      {'key': 'Separated', 'value': '53'},
#      {'key': 'Divorced', 'value': '166'},
#      {'key': 'Widowed', 'value': '58'}]},
#    {'key': 'Languages',
#     'value': [{'key': 'English', 'value': '1100'},
#      {'key': 'French', 'value': '24'},
#      {'key': 'Italian', 'value': '10'},
#      {'key': 'German', 'value': '10'},
#      {'key': 'Punjabi', 'value': '12'},
#      {'key': 'Cantonese', 'value': '64'},
#      {'key': 'Spanish', 'value': '53'},
#      {'key': 'Arabic', 'value': '19'},
#      {'key': 'Tagalog', 'value': '115'},
#      {'key': 'Portuguese', 'value': '4'},
#      {'key': 'Polish', 'value': '21'},
#      {'key': 'Mandarin', 'value': '99'},
#      {'key': 'Chinese n.o.s', 'value': '101'},
#      {'key': 'Vietnamese', 'value': '5'},
#      {'key': 'Persian', 'value': '72'},
#      {'key': 'Russian', 'value': '43'},
#      {'key': 'Dutch', 'value': '4'},
#      {'key': 'Korean', 'value': '120'},
#      {'key': 'Greek', 'value': '2'},
#      {'key': 'Tamil', 'value': '6'},
#      {'key': 'Romanian', 'value': '32'},
#      {'key': 'Hungarian', 'value': '3'},
#      {'key': 'Japanese', 'value': '25'},
#      {'key': 'Turkish', 'value': '7'},
#      {'key': 'Czech', 'value': '2'},
#      {'key': 'Somali', 'value': '2'},
#      {'key': 'Other Languages', 'value': '80'},
#      {'key': 'English & French', 'value': '3'},
#      {'key': 'English & Non-Official', 'value': '47'},
#      {'key': 'French & Non-Official', 'value': '8'}]},
#    {'key': 'Household income',
#     'value': [{'key': '$0 - $29,999', 'value': '161'},
#      {'key': '$30,000 - $59,999', 'value': '287'},
#      {'key': '$60,000 - $79,999', 'value': '180'},
#      {'key': '$80,000 - $99,999', 'value': '174'},
#      {'key': '$100,000 - $149,999', 'value': '219'},
#      {'key': '$150,000 - $199,999', 'value': '75'},
#      {'key': '$200,000+', 'value': '80'}]},
#    {'key': 'Children at Home',
#     'value': [{'key': '0 - 4 years old', 'value': '85'},
#      {'key': '5 - 9 years old', 'value': '29'},
#      {'key': '10 - 14 years old', 'value': '17'},
#      {'key': '15 - 19 years old', 'value': '17'},
#      {'key': '20 - 24 years old', 'value': '44'},
#      {'key': '25+ years old', 'value': '58'}]},
#    {'key': 'Ownership',
#     'value': [{'key': 'Own', 'value': '815'},
#      {'key': 'Rent', 'value': '361'}]},
#    {'key': 'Construction Date',
#     'value': [{'key': 'Before 1960', 'value': '50'},
#      {'key': '1961 - 1980', 'value': '58'},
#      {'key': '1981 - 1990', 'value': '116'},
#      {'key': '1991 - 2000', 'value': '221'},
#      {'key': '2001 - 2005', 'value': '37'},
#      {'key': '2006 - 2010', 'value': '383'},
#      {'key': '2011 - 2016', 'value': '226'},
#      {'key': 'After 2016', 'value': '85'}]},
#    {'key': 'Occupations',
#     'value': [{'key': 'Not Applicable', 'value': '48'},
#      {'key': 'Management', 'value': '154'},
#      {'key': 'Business, Finance, Admin', 'value': '357'},
#      {'key': 'Sciences', 'value': '241'},
#      {'key': 'Health', 'value': '120'},
#      {'key': 'Social Sciences, Education, Government, Religion',
#       'value': '219'},
#      {'key': 'Art, Culture, Recreation, Sport', 'value': '160'},
#      {'key': 'Sales and service', 'value': '295'},
#      {'key': 'Trades, Transport, Operators', 'value': '123'},
#      {'key': 'Manufacture and Utilities', 'value': '16'}]}]},
#  {'ErrorCode': {'Id': 200,
#    'Description': 'Success - OK',
#    'ProductName': 'Realtor API 7 | 20221109.3 | 660facef3b43c5755e5e5919321dc8bda7be3159 | Wednesday, November 9, 2022 10:42:45 AM',
#    'Version': '1.0.8348.28292'},
#   'Data': [{'key': '',
#     'value': [{'key': 'Daytime Population', 'value': '8590'},
#      {'key': 'Number of Businesses', 'value': '224'},
#      {'key': 'Population size', 'value': '550'},
#      {'key': 'Median age', 'value': '37.3'},
#      {'key': 'Average Household Size', 'value': '2.2'},
#      {'key': 'Average Household Income', 'value': '$86,399.31'},
#      {'key': 'Households with Children (%)', 'value': '58'},
#      {'key': 'Households without Children (%)', 'value': '42'},
#      {'key': 'Number of Households', 'value': '255'}]},
#    {'key': 'Retail Sales',
#     'value': [{'key': 'Unknown', 'value': '31'},
#      {'key': '< 1', 'value': '130'},
#      {'key': '1 - 4.9', 'value': '52'},
#      {'key': '5 - 19.9', 'value': '5'},
#      {'key': '20 - 99.9', 'value': '6'}]},
#    {'key': 'Population by Age Group',
#     'value': [{'key': '0 - 4 years old', 'value': '29'},
#      {'key': '5 - 9 years old', 'value': '19'},
#      {'key': '10 - 19 years old', 'value': '37'},
#      {'key': '20 - 34 years old', 'value': '181'},
#      {'key': '35 - 49 years old', 'value': '107'},
#      {'key': '50 - 54 years old', 'value': '54'},
#      {'key': '55 - 64 years old', 'value': '86'},
#      {'key': '65 - 69 years old', 'value': '18'},
#      {'key': '70 - 79 years old', 'value': '28'},
#      {'key': '80 - 84 years old', 'value': '9'},
#      {'key': '85+ years old', 'value': '4'}]},
#    {'key': 'Population Growth/Projection',
#     'value': [{'key': '2013', 'value': '569'},
#      {'key': '2018', 'value': '550'},
#      {'key': '2021', 'value': '613'},
#      {'key': '2023', 'value': '651'},
#      {'key': '2028', 'value': '799'}]},
#    {'key': 'Education',
#     'value': [{'key': 'No cert. / Diploma / Degree', 'value': '63'},
#      {'key': 'High school', 'value': '174'},
#      {'key': 'Apprenticeship / Trade cert. / Diploma', 'value': '91'},
#      {'key': 'Non-university cert. / Diploma', 'value': '49'},
#      {'key': 'University cert. / Diploma below bachelor', 'value': '56'},
#      {'key': 'University degree', 'value': '55'}]},
#    {'key': 'Marital Status',
#     'value': [{'key': 'Married', 'value': '179'},
#      {'key': 'Common law', 'value': '48'},
#      {'key': 'Single', 'value': '185'},
#      {'key': 'Separated', 'value': '15'},
#      {'key': 'Divorced', 'value': '47'},
#      {'key': 'Widowed', 'value': '14'}]},
#    {'key': 'Languages',
#     'value': [{'key': 'English', 'value': '263'},
#      {'key': 'French', 'value': '7'},
#      {'key': 'German', 'value': '6'},
#      {'key': 'Punjabi', 'value': '12'},
#      {'key': 'Cantonese', 'value': '11'},
#      {'key': 'Spanish', 'value': '18'},
#      {'key': 'Tagalog', 'value': '58'},
#      {'key': 'Mandarin', 'value': '31'},
#      {'key': 'Chinese n.o.s', 'value': '19'},
#      {'key': 'Russian', 'value': '9'},
#      {'key': 'Korean', 'value': '11'},
#      {'key': 'Hindi', 'value': '20'},
#      {'key': 'Turkish', 'value': '5'},
#      {'key': 'Other Languages', 'value': '39'},
#      {'key': 'English & Non-Official', 'value': '39'}]},
#    {'key': 'Household income',
#     'value': [{'key': '$0 - $29,999', 'value': '46'},
#      {'key': '$30,000 - $59,999', 'value': '128'},
#      {'key': '$60,000 - $79,999', 'value': '30'},
#      {'key': '$80,000 - $99,999', 'value': '14'},
#      {'key': '$100,000 - $149,999', 'value': '28'},
#      {'key': '$150,000 - $199,999', 'value': '3'},
#      {'key': '$200,000+', 'value': '6'}]},
#    {'key': 'Children at Home',
#     'value': [{'key': '0 - 4 years old', 'value': '23'},
#      {'key': '5 - 9 years old', 'value': '16'},
#      {'key': '10 - 14 years old', 'value': '14'},
#      {'key': '15 - 19 years old', 'value': '23'},
#      {'key': '20 - 24 years old', 'value': '28'},
#      {'key': '25+ years old', 'value': '24'}]},
#    {'key': 'Ownership',
#     'value': [{'key': 'Own', 'value': '133'},
#      {'key': 'Rent', 'value': '122'}]},
#    {'key': 'Construction Date',
#     'value': [{'key': 'Before 1960', 'value': '13'},
#      {'key': '1961 - 1980', 'value': '90'},
#      {'key': '1981 - 1990', 'value': '99'},
#      {'key': '1991 - 2000', 'value': '28'},
#      {'key': '2001 - 2005', 'value': '10'},
#      {'key': 'After 2016', 'value': '15'}]},
#    {'key': 'Occupations',
#     'value': [{'key': 'Not Applicable', 'value': '2'},
#      {'key': 'Management', 'value': '21'},
#      {'key': 'Business, Finance, Admin', 'value': '34'},
#      {'key': 'Sciences', 'value': '39'},
#      {'key': 'Health', 'value': '10'},
#      {'key': 'Social Sciences, Education, Government, Religion',
#       'value': '35'},
#      {'key': 'Art, Culture, Recreation, Sport', 'value': '7'},
#      {'key': 'Sales and service', 'value': '65'},
#      {'key': 'Trades, Transport, Operators', 'value': '98'},
#      {'key': 'Primary Industries', 'value': '6'}]}]},
#  {'ErrorCode': {'Id': 200,
#    'Description': 'Success - OK',
#    'ProductName': 'Realtor API 7 | 20221109.3 | 660facef3b43c5755e5e5919321dc8bda7be3159 | Wednesday, November 9, 2022 10:42:45 AM',
#    'Version': '1.0.8348.28292'},
#   'Data': [{'key': '',
#     'value': [{'key': 'Daytime Population', 'value': '20558'},
#      {'key': 'Number of Businesses', 'value': '1056'},
#      {'key': 'Population size', 'value': '501'},
#      {'key': 'Median age', 'value': '67.7'},
#      {'key': 'Average Household Size', 'value': '2.4'},
#      {'key': 'Average Household Income', 'value': '$98,279.93'},
#      {'key': 'Households with Children (%)', 'value': '42'},
#      {'key': 'Households without Children (%)', 'value': '58'},
#      {'key': 'Number of Households', 'value': '212'}]},
#    {'key': 'Retail Sales',
#     'value': [{'key': 'Unknown', 'value': '86'},
#      {'key': '< 1', 'value': '239'},
#      {'key': '1 - 4.9', 'value': '466'},
#      {'key': '5 - 19.9', 'value': '190'},
#      {'key': '20 - 99.9', 'value': '64'},
#      {'key': '100+ ', 'value': '11'}]},
#    {'key': 'Population by Age Group',
#     'value': [{'key': '0 - 4 years old', 'value': '10'},
#      {'key': '5 - 9 years old', 'value': '9'},
#      {'key': '10 - 19 years old', 'value': '42'},
#      {'key': '20 - 34 years old', 'value': '91'},
#      {'key': '35 - 49 years old', 'value': '66'},
#      {'key': '50 - 54 years old', 'value': '41'},
#      {'key': '55 - 64 years old', 'value': '102'},
#      {'key': '65 - 69 years old', 'value': '52'},
#      {'key': '70 - 79 years old', 'value': '111'},
#      {'key': '80 - 84 years old', 'value': '71'},
#      {'key': '85+ years old', 'value': '182'}]},
#    {'key': 'Population Growth/Projection',
#     'value': [{'key': '2013', 'value': '505'},
#      {'key': '2018', 'value': '501'},
#      {'key': '2021', 'value': '507'},
#      {'key': '2023', 'value': '499'},
#      {'key': '2028', 'value': '477'}]},
#    {'key': 'Education',
#     'value': [{'key': 'No cert. / Diploma / Degree', 'value': '64'},
#      {'key': 'High school', 'value': '134'},
#      {'key': 'Apprenticeship / Trade cert. / Diploma', 'value': '48'},
#      {'key': 'Non-university cert. / Diploma', 'value': '34'},
#      {'key': 'University cert. / Diploma below bachelor', 'value': '3'},
#      {'key': 'University degree', 'value': '185'}]},
#    {'key': 'Marital Status',
#     'value': [{'key': 'Married', 'value': '202'},
#      {'key': 'Common law', 'value': '22'},
#      {'key': 'Single', 'value': '82'},
#      {'key': 'Separated', 'value': '17'},
#      {'key': 'Divorced', 'value': '34'},
#      {'key': 'Widowed', 'value': '111'}]},
#    {'key': 'Languages',
#     'value': [{'key': 'English', 'value': '348'},
#      {'key': 'French', 'value': '10'},
#      {'key': 'German', 'value': '7'},
#      {'key': 'Punjabi', 'value': '73'},
#      {'key': 'Cantonese', 'value': '7'},
#      {'key': 'Spanish', 'value': '14'},
#      {'key': 'Polish', 'value': '3'},
#      {'key': 'Mandarin', 'value': '8'},
#      {'key': 'Ukrainian', 'value': '4'},
#      {'key': 'Dutch', 'value': '10'},
#      {'key': 'Japanese', 'value': '4'},
#      {'key': 'Turkish', 'value': '4'},
#      {'key': 'Other Languages', 'value': '9'}]},
#    {'key': 'Household income',
#     'value': [{'key': '$0 - $29,999', 'value': '35'},
#      {'key': '$30,000 - $59,999', 'value': '61'},
#      {'key': '$60,000 - $79,999', 'value': '28'},
#      {'key': '$80,000 - $99,999', 'value': '16'},
#      {'key': '$100,000 - $149,999', 'value': '38'},
#      {'key': '$150,000 - $199,999', 'value': '13'},
#      {'key': '$200,000+', 'value': '21'}]},
#    {'key': 'Children at Home',
#     'value': [{'key': '0 - 4 years old', 'value': '10'},
#      {'key': '5 - 9 years old', 'value': '9'},
#      {'key': '10 - 14 years old', 'value': '14'},
#      {'key': '15 - 19 years old', 'value': '24'},
#      {'key': '20 - 24 years old', 'value': '29'},
#      {'key': '25+ years old', 'value': '24'}]},
#    {'key': 'Ownership',
#     'value': [{'key': 'Own', 'value': '163'}, {'key': 'Rent', 'value': '49'}]},
#    {'key': 'Construction Date',
#     'value': [{'key': 'Before 1960', 'value': '47'},
#      {'key': '1961 - 1980', 'value': '56'},
#      {'key': '1981 - 1990', 'value': '9'},
#      {'key': '1991 - 2000', 'value': '13'},
#      {'key': '2001 - 2005', 'value': '56'},
#      {'key': '2006 - 2010', 'value': '8'},
#      {'key': '2011 - 2016', 'value': '22'}]},
#    {'key': 'Occupations',
#     'value': [{'key': 'Management', 'value': '58'},
#      {'key': 'Business, Finance, Admin', 'value': '147'},
#      {'key': 'Health', 'value': '2'},
#      {'key': 'Social Sciences, Education, Government, Religion', 'value': '9'},
#      {'key': 'Sales and service', 'value': '68'},
#      {'key': 'Trades, Transport, Operators', 'value': '44'},
#      {'key': 'Primary Industries', 'value': '22'}]}]}]

# %%
jsonfile[2]['Data'][0]['value'][2]['value']
# Out:
# '561'

# %%
data_1 = pd.DataFrame(jsonfile[0]['Data'][0]['value'])
data_1
# Out:
#                                key       value
# 0               Daytime Population       47285
# 1             Number of Businesses        2196
# 2                  Population size        3223
# 3                       Median age        34.4
# 4           Average Household Size         1.6
# 5         Average Household Income  $81,129.77
# 6     Households with Children (%)          28
# 7  Households without Children (%)          72
# 8             Number of Households        1954

# %%
pd.DataFrame(jsonfile[0]['Data'][1]['value'])
# Out:
#          key value
# 0    Unknown   621
# 1        < 1   902
# 2    1 - 4.9   482
# 3   5 - 19.9   126
# 4  20 - 99.9    58
# 5      100+      7

# %%
temp = [float(jsonfile[x]['Data'][0]['value'][2]['value'].replace("$","").replace(",","")) for x in range(df.shape[0]) ]


new_df  = pd.DataFrame({'city': df['City'],
                        'Population': temp })

# %%
new_df
px.bar(new_df, x='city', y='Population',color='Population',orientation='v')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="26085b3e-30cc-48dd-acdb-0d36b7ac97fb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("26085b3e-30cc-48dd-acdb-0d36b7ac97fb")) {                    Plotly.newPlot(                        "26085b3e-30cc-48dd-acdb-0d36b7ac97fb",                        [{"alignmentgroup":"True","hovertemplate":"city=%{x}<br>Population=%{marker.color}<extra></extra>","legendgroup":"","marker":{"color":[3223.0,1067.0,561.0,883.0,535.0,5989.0,1031.0,2095.0,550.0,501.0],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Vancouver, BC, Canada","North Vancouver, BC, Canada","West Vancouver, BC, Canada","Richmond, BC, Canada","Burnaby, BC, Canada","Coquitlam, BC, Canada","Port Moody, BC, Canada","New Westminster, BC, Canada","Surrey, BC, Canada","Delta, BC, Canada"],"xaxis":"x","y":[3223.0,1067.0,561.0,883.0,535.0,5989.0,1031.0,2095.0,550.0,501.0],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"# ...

# %%
temp = [float(jsonfile[x]['Data'][0]['value'][4]['value'].replace("$","").replace(",","")) for x in range(df.shape[0]) ]


new_df  = pd.DataFrame({'city': df['City'],
                        'Average Household Size': temp })


px.bar(new_df, x='city', y='Average Household Size',color='Average Household Size',orientation='v')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="e8e6cf62-aeaa-4ced-bb96-6306b7dd9359" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e8e6cf62-aeaa-4ced-bb96-6306b7dd9359")) {                    Plotly.newPlot(                        "e8e6cf62-aeaa-4ced-bb96-6306b7dd9359",                        [{"alignmentgroup":"True","hovertemplate":"city=%{x}<br>Average Household Size=%{marker.color}<extra></extra>","legendgroup":"","marker":{"color":[1.6,2.0,1.7,2.2,3.1,2.0,2.5,1.8,2.2,2.4],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Vancouver, BC, Canada","North Vancouver, BC, Canada","West Vancouver, BC, Canada","Richmond, BC, Canada","Burnaby, BC, Canada","Coquitlam, BC, Canada","Port Moody, BC, Canada","New Westminster, BC, Canada","Surrey, BC, Canada","Delta, BC, Canada"],"xaxis":"x","y":[1.6,2.0,1.7,2.2,3.1,2.0,2.5,1.8,2.2,2.4],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"} ...

# %%
temp = [float(jsonfile[x]['Data'][0]['value'][5]['value'].replace("$","").replace(",","")) for x in range(df.shape[0]) ]


new_df  = pd.DataFrame({'city': df['City'],
                        'Median Income': temp })


px.bar(new_df, x='city', y='Median Income',color='Median Income',orientation='v')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="b5a37101-2a1e-4ae5-8288-773a5f80534a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b5a37101-2a1e-4ae5-8288-773a5f80534a")) {                    Plotly.newPlot(                        "b5a37101-2a1e-4ae5-8288-773a5f80534a",                        [{"alignmentgroup":"True","hovertemplate":"city=%{x}<br>Median Income=%{marker.color}<extra></extra>","legendgroup":"","marker":{"color":[81129.77,72428.15,83160.77,62573.07,88593.16,61662.28,102134.85,138014.25,86399.31,98279.93],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Vancouver, BC, Canada","North Vancouver, BC, Canada","West Vancouver, BC, Canada","Richmond, BC, Canada","Burnaby, BC, Canada","Coquitlam, BC, Canada","Port Moody, BC, Canada","New Westminster, BC, Canada","Surrey, BC, Canada","Delta, BC, Canada"],"xaxis":"x","y":[81129.77,72428.15,83160.77,62573.07,88593.16,61662.28,102134.85,138014.25,86399.31,98279.93],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.777777777 ...

# %%
pd.DataFrame(jsonfile[0]['Data'][3]['value'])['value'].tolist()
# Out:
# ['2576', '3223', '3683', '3976', '4579']

# %%
new_df = []
for i in range(df.shape[0]):
  new_df.append(pd.DataFrame(jsonfile[i]['Data'][3]['value'])['value'].tolist())

# %%
pd.DataFrame(jsonfile[0]['Data'][3]['value'])
# Out:
#     key value
# 0  2013  2576
# 1  2018  3223
# 2  2021  3683
# 3  2023  3976
# 4  2028  4579

# %%
df_pop_proj = pd.DataFrame(new_df,columns = pd.DataFrame(jsonfile[0]['Data'][3]['value'])['key'].tolist() ,index = df['City'].tolist())

# %%
df_pop_proj = df_pop_proj.apply(pd.to_numeric)
df_pop_proj
# Out:
#                              2013  2018  2021  2023  2028
# Vancouver, BC, Canada        2576  3223  3683  3976  4579
# North Vancouver, BC, Canada  1006  1067  1220  1321  1595
# West Vancouver, BC, Canada   6030   561  6376  6534  6898
# Richmond, BC, Canada          901   883   890   895   903
# Burnaby, BC, Canada           402   535   556   569   584
# Coquitlam, BC, Canada        4112  5989  6576  6973  8000
# Port Moody, BC, Canada       1048  1031  1035  1040  1030
# New Westminster, BC, Canada  1757  2095  2491  2753  3637
# Surrey, BC, Canada            569   550   613   651   799
# Delta, BC, Canada             505   501   507   499   477

# %%
new_df = pd.melt(df_pop_proj, value_vars = df_pop_proj.columns, var_name='Year',value_name='Population',ignore_index=False)
new_df

# %%
px.line(new_df,x='Year',y='Population',color=new_df.index,animation_frame=new_df.index,range_y=[0,10000])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="7a2a2daa-6e9d-4c29-8a21-d8ac3d181a05" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7a2a2daa-6e9d-4c29-8a21-d8ac3d181a05")) {                    Plotly.newPlot(                        "7a2a2daa-6e9d-4c29-8a21-d8ac3d181a05",                        [{"hovertemplate":"index=Vancouver, BC, Canada<br>Year=%{x}<br>Population=%{y}<extra></extra>","legendgroup":"Vancouver, BC, Canada","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Vancouver, BC, Canada","orientation":"v","showlegend":true,"x":["2013","2018","2021","2023","2028"],"xaxis":"x","y":[2576,3223,3683,3976,4579],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""} ...
